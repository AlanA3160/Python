# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanA3160/Python/blob/main/Week16/Week16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT STATEMENTS

#FUNCTION DEFINITIONS
#Def add_expense(expense_list)
def add_expense(expense_list):
    #Ask user for the Category, Vendor, Date
    category = input("Enter the category:")
    vendor = input("Enter the vendor:")
    date = input("Enter the date:")
    #Use try/except to get a dollar amount
    try:
        amount = float(input("Enter Amount: "))
    except ValueError:
        print("invalid amount, no record saved")
        return
    #Create a dictionary for the single expense
    expense = {"category": category,
               "vendor": vendor,
               "date": date,
               "amount": amount
               }
    #Append dictionary to the main expense_list
    expense_list.append(expense)
    #Print appended saved
    print("Expense Saved")

#Def show_report(expense_list, filter_type):
#Set total to 0.0
#If Statements to Iterate through the list(All, Category, Vendor,)
#Sum Amounts based on filter_type (All, Category, Vendor)
#Print formatted total (2 decimal places)


#PROGRAM LOGIC
# Initialize list (all_expenses)
all_expenses = []
# While true loop for continuous entry
while True:
  print("1. Add Expense")
  print("2. Show Report")
  print("3. Quit")
# Print Add, Total, Category, vendor, Quit
# user input for choice
  choice = input("Select an option: ")
# If statement for handling user input, call function
  if choice == "1":
    add_expense(all_expenses)
  elif choice == "2":
    print("\nCurrent Expenses:")
    print(all_expenses)
  elif choice == "3":
    print("Goodbye!")
    break
# Out:
# 1. Add Expense
# 2. Show Report
# 3. Quit
# Select an option: 1
# Enter the category:gas
# Enter the vendor:shell
# Enter the date:05/10/26
# Enter Amount: 50.00
# Expense Saved
# 1. Add Expense
# 2. Show Report
# 3. Quit
# Select an option: 1
# Enter the category:food
# Enter the vendor:walmart
# Enter the date:05/11/26
# Enter Amount: 75.00
# Expense Saved
# 1. Add Expense
# 2. Show Report
# 3. Quit
# Select an option: 2
#
# Current Expenses:
# [{'category': 'gas', 'vendor': 'shell', 'date': '05/10/26', 'amount': 50.0}, {'category': 'food', 'vendor': 'walmart', 'date': '05/11/26', 'amount': 75.0}]
# 1. Add Expense
# 2. Show Report
# 3. Quit
# Select an option: 3
# Goodbye!
